# %% [markdown]
# <a href="https://colab.research.google.com/github/xtenix88/Data-Portfolio/blob/main/Stackoverflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
df = pd.read_csv('/content/survey_results_public.csv', error_bad_lines=False)

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.head(5)
# Out:
#    ResponseId  ... ConvertedCompYearly
# 0           1  ...             62268.0
# 1           2  ...                 NaN
# 2           3  ...                 NaN
# 3           4  ...                 NaN
# 4           5  ...                 NaN
#
# [5 rows x 48 columns]

# %%
coding_language = df['LanguageWantToWorkWith'].str.split(';')
#coding_language = df['LanguageWantToWorkWith'].str.split(';', expand=True)
coding_language
# Out:
# 0                                                  [Swift]
# 1                                                      NaN
# 2                                    [Julia, Python, Rust]
# 3                                 [JavaScript, TypeScript]
# 4                      [Bash/Shell, HTML/CSS, Python, SQL]
#                                ...
# 83434                                            [Clojure]
# 83435                                                  NaN
# 83436                                       [Java, Python]
# 83437                                           [Go, Rust]
# 83438    [Elixir, HTML/CSS, Java, JavaScript, Node.js, ...
# Name: LanguageWantToWorkWith, Length: 83439, dtype: object

# %%
type(coding_language)
# Out:
# pandas.core.series.Series

# %%
type(coding_language[0]) #list
# Out:
# list

# %%
coding_language.str.get(1) #get the second element, position 1
# Out:
# 0               NaN
# 1               NaN
# 2            Python
# 3        TypeScript
# 4          HTML/CSS
#             ...
# 83434           NaN
# 83435           NaN
# 83436        Python
# 83437          Rust
# 83438      HTML/CSS
# Name: LanguageWantToWorkWith, Length: 83439, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Employment',
#  'Country',
#  'US_State',
#  'UK_Country',
#  'EdLevel',
#  'Age1stCode',
#  'LearnCode',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'Currency',
#  'CompTotal',
#  'CompFreq',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'OpSys',
#  'NEWStuck',
#  'NEWSOSites',
#  'SOVisitFreq',
#  'SOAccount',
#  'SOPartFreq',
#  'SOComm',
#  'NEWOtherComms',
#  'Age',
#  'Gender',
#  'Trans',
#  'Sexuality',
#  'Ethnicity',
#  'Accessibility',
#  'MentalHealth',
#  'SurveyLength',
#  'SurveyEase',
#  'ConvertedCompYearly']

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# UK_Country                      79021
# US_State                        68519
# MiscTechWantToWorkWith          45418
# PlatformWantToWorkWith          41820
# ConvertedCompYearly             36595
# MiscTechHaveWorkedWith          36384
# CompTotal                       36256
# WebframeWantToWorkWith          31344
# PlatformHaveWorkedWith          31304
# CompFreq                        31289
# DatabaseWantToWorkWith          25140
# OrgSize                         22713
# Currency                        22359
# YearsCodePro                    22223
# WebframeHaveWorkedWith          21732
# ToolsTechWantToWorkWith         17959
# DevType                         16955
# SOPartFreq                      15886
# DatabaseHaveWorkedWith          13893
# ToolsTechHaveWorkedWith         10902
# NEWCollabToolsWantToWorkWith    10417
# Sexuality                       10073
# LanguageWantToWorkWith           6618
# MentalHealth                     6519
# Accessibility                    5836
# ...

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time                                      53584
# Student, full-time                                      11781
# Independent contractor, freelancer, or self-employed     8041
# Not employed, but looking for work                       2961
# Employed part-time                                       2461
# Student, part-time                                       2051
# Not employed, and not looking for work                   1228
# I prefer not to say                                       890
# Retired                                                   326
# Name: Employment, dtype: int64

# %%
df.loc[ (df['Country']=='United States of America') & (df['US_State']=='Texas'), ['Employment', 'YearsCode']]
# Out:
#                                               Employment YearsCode
# 63                                    Student, full-time         5
# 251                                  I prefer not to say       NaN
# 278                                   Employed full-time        18
# 314                                   Student, full-time         5
# 347                                   Employed full-time        25
# ...                                                  ...       ...
# 83233                                 Employed full-time        26
# 83295  Independent contractor, freelancer, or self-em...         8
# 83312                                 Employed full-time        14
# 83367  Independent contractor, freelancer, or self-em...         3
# 83434                                 Employed full-time         6
#
# [1023 rows x 2 columns]

# %%
df.head(2)
# Out:
#    ResponseId  ... ConvertedCompYearly
# 0           1  ...             62268.0
# 1           2  ...                 NaN
#
# [2 rows x 48 columns]

# %%
df_long = pd.melt(
      df, 
      id_vars=["ResponseId","MainBranch","Employment"])
df_long
# Out:
#          ResponseId  ...                                              value
# 0                 1  ...                                           Slovakia
# 1                 2  ...                                        Netherlands
# 2                 3  ...                                 Russian Federation
# 3                 4  ...                                            Austria
# 4                 5  ...  United Kingdom of Great Britain and Northern I...
# ...             ...  ...                                                ...
# 3754750       83435  ...                                             160500
# 3754751       83436  ...                                               3960
# 3754752       83437  ...                                              90000
# 3754753       83438  ...                                             816816
# 3754754       83439  ...                                              21168
#
# [3754755 rows x 5 columns]

# %%
filt = df['US_State'] == 'Texas'

# %%
df.loc[filt, ['Employment',"YearsCode", 'ConvertedCompYearly']].sort_values(by='ConvertedCompYearly', ascending=False)
# Out:
#                                               Employment  ... ConvertedCompYearly
# 20908                                 Employed full-time  ...          10000000.0
# 66417                                 Employed full-time  ...           9100000.0
# 8623                                  Employed full-time  ...           6500000.0
# 5288                                  Employed full-time  ...           3850000.0
# 27070                                 Employed full-time  ...           3250000.0
# ...                                                  ...  ...                 ...
# 81847             Not employed, and not looking for work  ...                 NaN
# 81999                                 Employed part-time  ...                 NaN
# 82241  Independent contractor, freelancer, or self-em...  ...                 NaN
# 82481  Independent contractor, freelancer, or self-em...  ...                 NaN
# ...

# %%
df.nlargest(5, 'ConvertedCompYearly')
# Out:
#        ResponseId  ... ConvertedCompYearly
# 66910       66911  ...          45241312.0
# 65399       65400  ...          30468516.0
# 40586       40587  ...          21822250.0
# 28791       28792  ...          20000000.0
# 12700       12701  ...          19200000.0
#
# [5 rows x 48 columns]

# %%
df.ConvertedCompYearly.median()
# Out:
# 56211.0

# %%
df.ConvertedCompYearly.count()
# Out:
# 46844

# %%
df.SOAccount.value_counts()
# Out:
# Yes                        67813
# No                         10510
# Not sure/can't remember     4202
# Name: SOAccount, dtype: int64

# %%
df.Country.value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Tuvalu                                                      1
# Saint Vincent and the Grenadines                            1
# Papua New Guinea                                            1
# Dominica                                                    1
# Name: Country, Length: 181, dtype: int64

# %%
state_grp = df.groupby(['US_State']) #groupby split up the states
state_grp.get_group('Texas').head(5)
# Out:
#      ResponseId  ... ConvertedCompYearly
# 63           64  ...                 NaN
# 251         252  ...                 NaN
# 278         279  ...            160000.0
# 314         315  ...                 NaN
# 347         348  ...            120000.0
#
# [5 rows x 48 columns]

# %%
filt = df['US_State'] == 'Texas'
df.loc[filt]['MainBranch'].value_counts() #using a filter
# Out:
# I am a developer by profession                                                   728
# I am not primarily a developer, but I write code sometimes as part of my work    105
# I am a student who is learning to code                                            91
# I code primarily as a hobby                                                       72
# I used to be a developer by profession, but no longer am                          15
# None of these                                                                     12
# Name: MainBranch, dtype: int64

# %%
state_grp['MainBranch'].value_counts().loc['Texas'] #without using a filter
state_grp['MainBranch'].value_counts(normalize=True).loc['Texas'] #without using a filter and in percentage
# Out:
# MainBranch
# I am a developer by profession                                                   0.711632
# I am not primarily a developer, but I write code sometimes as part of my work    0.102639
# I am a student who is learning to code                                           0.088954
# I code primarily as a hobby                                                      0.070381
# I used to be a developer by profession, but no longer am                         0.014663
# None of these                                                                    0.011730
# Name: MainBranch, dtype: float64

# %%
state_grp['DevType'].value_counts(normalize=True).loc['Texas']
# Out:
# DevType
# Developer, full-stack                                                                  0.138889
# Developer, back-end                                                                    0.069444
# Other (please specify):                                                                0.035880
# Developer, front-end                                                                   0.031250
# Developer, embedded applications or devices                                            0.027778
#                                                                                          ...
# Other (please specify):;System administrator                                           0.001157
# Senior Executive (C-Suite, VP, etc.);Marketing or sales professional                   0.001157
# Student;Data or business analyst                                                       0.001157
# Student;Developer, embedded applications or devices                                    0.001157
# ...

# %%
state_grp['ConvertedCompYearly'].median().sort_values(ascending=False).head(10)
# Out:
# US_State
# Washington       170000.0
# California       160000.0
# Hawaii           145000.0
# New Jersey       144000.0
# New Hampshire    143500.0
# New York         140500.0
# Massachusetts    140000.0
# Delaware         135000.0
# Nevada           130000.0
# Colorado         130000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
state_grp['ConvertedCompYearly'].median().loc['Texas']
# Out:
# 125000.0

# %%
state_grp['ConvertedCompYearly'].agg(['median', 'mean']).loc[['Texas','New Jersey']]
# Out:
#               median           mean
# US_State
# Texas       125000.0  202891.460507
# New Jersey  144000.0  378878.612565

# %%
state_grp['DevType'].value_counts().loc['Texas'].sum() #without using a filter
# Out:
# 864

# %%
filt = df['US_State'] == 'Texas'
df.loc[filt]['DevType'].str.contains('Data').sum()
# Out:
# 157

# %%
df.loc[filt]['DevType'].str.contains('analyst').sum()
# Out:
# 70

# %%
state_grp['DevType'].value_counts(normalize=True).loc['Texas']
# Out:
# DevType
# Developer, full-stack                                                                  0.138889
# Developer, back-end                                                                    0.069444
# Other (please specify):                                                                0.035880
# Developer, front-end                                                                   0.031250
# Developer, embedded applications or devices                                            0.027778
#                                                                                          ...
# Other (please specify):;System administrator                                           0.001157
# Senior Executive (C-Suite, VP, etc.);Marketing or sales professional                   0.001157
# Student;Data or business analyst                                                       0.001157
# Student;Developer, embedded applications or devices                                    0.001157
# ...

# %%
state_grp['DevType'].apply(lambda x: x.str.contains('Data').sum())
# Out:
# US_State
# Alabama                                  12
# Alaska                                    2
# American Samoa                            0
# Arizona                                  44
# Arkansas                                 10
# California                              300
# Colorado                                 81
# Connecticut                              18
# Delaware                                  3
# District of Columbia                     22
# Florida                                  96
# Georgia                                  51
# Guam                                      0
# Hawaii                                    4
# I do not reside in the United States      0
# Idaho                                    21
# Illinois                                 77
# Indiana                                  37
# Iowa                                     25
# Kansas                                   21
# Kentucky                                 18
# ...

# %%
state_respondents = df['US_State'].value_counts()
state_uses_SQL = state_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('SQL').sum())
state_data_career = state_grp['DevType'].apply(lambda x: x.str.contains('Data').sum())

# %%
sql_df = pd.concat([state_respondents, state_uses_SQL, state_data_career], axis='columns', sort=True)
sql_df.rename(columns={'US_State': "NumRespondents", 'LanguageHaveWorkedWith': 'LanguageHaveWorkedWith:SQL', 'DevType':'DataField'}, inplace=True)

# %%
sql_df.head(10)
# Out:
#                       NumRespondents  LanguageHaveWorkedWith:SQL  DataField
# Alabama                          116                          51         12
# Alaska                            21                          12          2
# American Samoa                     1                           0          0
# Arizona                          261                         142         44
# Arkansas                          64                          37         10
# California                      2163                         927        300
# Colorado                         549                         243         81
# Connecticut                      128                          68         18
# Delaware                          21                           9          3
# District of Columbia              81                          45         22

# %%
sql_df['PercentageKnowSQL'] = (sql_df['LanguageHaveWorkedWith:SQL']/sql_df['NumRespondents']) *100
sql_df['PercentageInDataField'] = (sql_df['DataField']/sql_df['NumRespondents']) *100

# %%
sql_df.head(20)
# Out:
#                                       NumRespondents  ...  PercentageInDataField
# Alabama                                          116  ...              10.344828
# Alaska                                            21  ...               9.523810
# American Samoa                                     1  ...               0.000000
# Arizona                                          261  ...              16.858238
# Arkansas                                          64  ...              15.625000
# California                                      2163  ...              13.869626
# Colorado                                         549  ...              14.754098
# Connecticut                                      128  ...              14.062500
# Delaware                                          21  ...              14.285714
# District of Columbia                              81  ...              27.160494
# Florida                                          613  ...              15.660685
# ...

# %%
sql_df.loc["Texas"]
# Out:
# NumRespondents                1023.000000
# LanguageHaveWorkedWith:SQL     489.000000
# DataField                      157.000000
# PercentageKnowSQL               47.800587
# PercentageInDataField           15.347019
# Name: Texas, dtype: float64

# %%
# Out:
#    ResponseId  ... ConvertedCompYearly
# 0           1  ...             62268.0
# 1           2  ...                 NaN
# 2           3  ...                 NaN
# 3           4  ...                 NaN
# 4           5  ...                 NaN
#
# [5 rows x 48 columns]

# %%
df.isna().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EdLevel                           313
# Age1stCode                        196
# LearnCode                         476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# CompTotal                       36256
# CompFreq                        31289
# LanguageHaveWorkedWith           1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].value_counts().sort_values()
# Out:
# 49                      30
# 48                      33
# 47                      52
# 50                      58
# 46                      67
# 44                      90
# 43                     124
# 45                     156
# More than 50 years     170
# 41                     179
# 29                     197
# 42                     203
# 39                     205
# 31                     219
# 36                     264
# 34                     268
# 33                     309
# 37                     329
# 32                     331
# 38                     361
# 28                     455
# 27                     492
# 26                     533
# 24                     639
# 19                     659
# 23                     811
# 40                     830
# 21                     863
# 22                     941
# 35                    1007
# 17                    1331
# 18                    1386
# Less than 1 year      1489
# 16                    1491
# ...

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True )

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True )

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')

df2 = pd.read_csv('/content/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.

# %%
df2.head(5)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df2.loc[0, 'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df2.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df2['Date'].dt.day_name() #access the whole series
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df2['DayOfWeek'] = df2['Date'].dt.day_name()

# %%
df2.head(2)
# Out:
#                  Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 0 2020-03-13 20:00:00  ETHUSD  129.94  ...  128.71  1940673.93     Friday
# 1 2020-03-13 19:00:00  ETHUSD  119.51  ...  129.94  7579741.09     Friday
#
# [2 rows x 8 columns]

# %%
df2['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df2['Date'].max() - df2['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df2['Date'] >= pd.to_datetime('2019-01-01')) & (df2['Date'] < pd.to_datetime('2020-01-01'))
df2.loc[filt]
# Out:
#                      Date  Symbol    Open  ...   Close      Volume  DayOfWeek
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  ...  128.54   440678.91    Tuesday
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  ...  128.33   554646.02    Tuesday
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  ...  128.38   350155.69    Tuesday
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  ...  127.86   428183.38    Tuesday
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  ...  127.84  1169847.84    Tuesday
# ...                   ...     ...     ...  ...     ...         ...        ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  ...  131.96  2791135.37    Tuesday
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  ...  130.75   503732.63    Tuesday
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  ...  130.06   838183.43    Tuesday
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  ...  130.79   434917.99    Tuesday
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  ...  131.62  1067136.21    Tuesday
#
# [8760 rows x 8 columns]

# %%
df2['Date'].max() - df2['Date'].min()

# %%
df2.set_index('Date', inplace=True)

# %%
df2['2019'] #set date as index, now find date
# Out:
#                      Symbol    Open    High  ...   Close      Volume  DayOfWeek
# Date                                         ...
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  ...  128.54   440678.91    Tuesday
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  ...  128.33   554646.02    Tuesday
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  ...  128.38   350155.69    Tuesday
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  ...  127.86   428183.38    Tuesday
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  ...  127.84  1169847.84    Tuesday
# ...                     ...     ...     ...  ...     ...         ...        ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  ...  131.96  2791135.37    Tuesday
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  ...  130.75   503732.63    Tuesday
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  ...  130.06   838183.43    Tuesday
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  ...  130.79   434917.99    Tuesday
# ...

# %%
df2['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
df2['2020-01']['Open']
# Out:
# Date
# 2020-01-31 23:00:00    181.73
# 2020-01-31 22:00:00    180.66
# 2020-01-31 21:00:00    180.31
# 2020-01-31 20:00:00    179.19
# 2020-01-31 19:00:00    179.10
#                         ...
# 2020-01-01 04:00:00    129.57
# 2020-01-01 03:00:00    130.37
# 2020-01-01 02:00:00    130.14
# 2020-01-01 01:00:00    128.34
# 2020-01-01 00:00:00    128.54
# Name: Open, Length: 744, dtype: float64

# %%
df2['2020-01']['Open'].mean()
# Out:
# 155.01692204301062

# %%
df2['2020-01']['Open'].max()
# Out:
# 186.62

# %%
highs = df2['Open'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.55

# %%
import matplotlib
# %matplotlib inline

# %%
highs.plot()

# %%
df2.resample('W').agg({'Close':'mean', 'High':'max', 'Low':'min', 'Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
india_df = df.loc[df['Country'] == 'India']

# %%
india_df.to_csv('/content/india.csv')

# %%
india_df.to_excel('/content/india.xlsx')

# %%
# Out:
#        ResponseId  ... DayOfWeek
# 0               1  ...    Friday
# 1               2  ...    Friday
# 2               3  ...    Friday
# 3               4  ...    Friday
# 4               5  ...    Friday
# ...           ...  ...       ...
# 83434       83435  ...       NaN
# 83435       83436  ...       NaN
# 83436       83437  ...       NaN
# 83437       83438  ...       NaN
# 83438       83439  ...       NaN
#
# [83439 rows x 49 columns]

# %%
df = pd.read_csv('/content/Sales_April_2019.csv')
df.head(5)
# Out:
#   Order ID  ...                      Purchase Address
# 0   176558  ...          917 1st St, Dallas, TX 75001
# 1      NaN  ...                                   NaN
# 2   176559  ...     682 Chestnut St, Boston, MA 02215
# 3   176560  ...  669 Spruce St, Los Angeles, CA 90001
# 4   176560  ...  669 Spruce St, Los Angeles, CA 90001
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (18383, 6)
